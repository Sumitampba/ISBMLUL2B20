# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/sumit/Desktop/ISB/Classwork/Python/Assignment/earthquake.csv')
display(df)
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
df.shape
# Out:
# (23412, 21)

# %%
df.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Date                              0
# Time                              0
# Latitude                          0
# Longitude                         0
# Type                              0
# Depth                             0
# Depth Error                   18951
# Depth Seismic Stations        16315
# Magnitude                         0
# Magnitude Type                    3
# Magnitude Error               23085
# Magnitude Seismic Stations    20848
# Azimuthal Gap                 16113
# Horizontal Distance           21808
# Horizontal Error              22256
# Root Mean Square               6060
# ID                                0
# Source                            0
# Location Source                   0
# Magnitude Source                  0
# Status                            0
# dtype: int64

# %%
df.drop(['Depth Error','Depth Seismic Stations','Magnitude Error','Magnitude Seismic Stations','Azimuthal Gap','Horizontal Distance','Horizontal Error'], axis = 1, inplace = True)
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type  Root Mean Square            ID  Source  \
# ...

# %%
df['Root Mean Square'].fillna(df['Root Mean Square'].median(), inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['Root Mean Square'].fillna(df['Root Mean Square'].median(), inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# Latitude            0
# Longitude           0
# Type                0
# Depth               0
# Magnitude           0
# Magnitude Type      3
# Root Mean Square    0
# ID                  0
# Source              0
# Location Source     0
# Magnitude Source    0
# Status              0
# dtype: int64

# %%
display(df)
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type  Root Mean Square            ID  Source  \
# ...

# %%
df['Type'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df['Type'].unique()
#
# NameError: name 'df' is not defined

# %%
df['Type'].value_counts()
# Out:
# Type
# Earthquake           23232
# Nuclear Explosion      175
# Explosion                4
# Rock Burst               1
# Name: count, dtype: int64

# %%
df.drop(df[(df['Type']=='Explosion')].index, inplace=True)
df['Type'].value_counts()
# Out:
# Type
# Earthquake           23232
# Nuclear Explosion      175
# Rock Burst               1
# Name: count, dtype: int64

# %%
df.drop(df[(df['Type']=='Nuclear Explosion')].index, inplace=True)
df['Type'].value_counts()
# Out:
# Type
# Earthquake    23232
# Rock Burst        1
# Name: count, dtype: int64

# %%
df.drop(df[(df['Type']=='Rock Burst')].index, inplace=True)
df['Type'].value_counts()
# Out:
# Type
# Earthquake    23232
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (23232, 14)

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# Latitude            0
# Longitude           0
# Type                0
# Depth               0
# Magnitude           0
# Magnitude Type      3
# Root Mean Square    0
# ID                  0
# Source              0
# Location Source     0
# Magnitude Source    0
# Status              0
# dtype: int64

# %%
df[df['Magnitude Type'].isna()]
# Out:
#             Date      Time  Latitude  Longitude        Type  Depth  Magnitude  \
# 6703  08/24/1983  13:36:00   40.3732  -124.9227  Earthquake  11.93       5.70
# 7294  11/23/1984  18:08:00   37.4600  -118.5900  Earthquake   9.00       5.82
# 7919  03/31/1986  11:55:00   37.4788  -121.6858  Earthquake   9.17       5.60
#
#      Magnitude Type  Root Mean Square                   ID Source  \
# 6703            NaN               1.0  ATLAS19830824133600  ATLAS
# 7294            NaN               1.0  ATLAS19841123180800  ATLAS
# 7919            NaN               1.0  ATLAS19860331115500  ATLAS
#
#      Location Source Magnitude Source     Status
# 6703           ATLAS            ATLAS  Automatic
# 7294           ATLAS            ATLAS  Automatic
# 7919           ATLAS            ATLAS  Automatic

# %%
df.drop(df[df['Magnitude Type'].isna()].index, inplace=True)

# %%
df[df['Magnitude Type'].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Latitude, Longitude, Type, Depth, Magnitude, Magnitude Type, Root Mean Square, ID, Source, Location Source, Magnitude Source, Status]
# Index: []

# %%
df.isnull().sum()
# Out:
# Date                0
# Time                0
# Latitude            0
# Longitude           0
# Type                0
# Depth               0
# Magnitude           0
# Magnitude Type      0
# Root Mean Square    0
# ID                  0
# Source              0
# Location Source     0
# Magnitude Source    0
# Status              0
# dtype: int64

# %%
max(df['Magnitude'])      #Highest Magnitude Scale Earthquake since all other types areremoved from the data set.
# Out:
# 9.1

# %%
print("Skewness: %f" % df['Magnitude'].skew())
# Out:
# Skewness: 1.846881

# %%
print("Skewness: %f" % df['Depth'].skew())
# Out:
# Skewness: 3.278553

# %%
df['Magnitude'].describe()
# Out:
# count    23229.000000
# mean         5.882785
# std          0.424053
# min          5.500000
# 25%          5.600000
# 50%          5.700000
# 75%          6.000000
# max          9.100000
# Name: Magnitude, dtype: float64

# %%
df['Depth'].describe()
# Out:
# count    23229.000000
# mean        71.321828
# std        122.974352
# min         -1.100000
# 25%         15.000000
# 50%         33.000000
# 75%         54.800000
# max        700.000000
# Name: Depth, dtype: float64

# %%
sns.distplot(df['Magnitude']);

# %%
sns.distplot(df['Depth']);

# %%
#histogram and normal probability plot
sns.distplot(df['Depth'], fit=norm);
fig = plt.figure()
res = stats.probplot(df['Depth'], plot=plt)

# %%
df['Date']
# Out:
# 0        01/02/1965
# 1        01/04/1965
# 2        01/05/1965
# 3        01/08/1965
# 4        01/09/1965
#             ...
# 23407    12/28/2016
# 23408    12/28/2016
# 23409    12/28/2016
# 23410    12/29/2016
# 23411    12/30/2016
# Name: Date, Length: 23229, dtype: object

# %%
mystr = df['Date'].str.replace('/', '')
mystr
# Out:
# 0        01021965
# 1        01041965
# 2        01051965
# 3        01081965
# 4        01091965
#            ...
# 23407    12282016
# 23408    12282016
# 23409    12282016
# 23410    12292016
# 23411    12302016
# Name: Date, Length: 23229, dtype: object

# %%
df['Year'] = mystr.str.strip().str[-4:]
df['Year']
# Out:
# 0        1965
# 1        1965
# 2        1965
# 3        1965
# 4        1965
#          ...
# 23407    2016
# 23408    2016
# 23409    2016
# 23410    2016
# 23411    2016
# Name: Year, Length: 23229, dtype: object

# %%
df['Day'] = mystr.str.strip().str[:2]
df['Day']
# Out:
# 0        01
# 1        01
# 2        01
# 3        01
# 4        01
#          ..
# 23407    12
# 23408    12
# 23409    12
# 23410    12
# 23411    12
# Name: Day, Length: 23229, dtype: object

# %%
df['Month'] = mystr.str.strip().str[2:4]
df['Month']
# Out:
# 0        02
# 1        04
# 2        05
# 3        08
# 4        09
#          ..
# 23407    28
# 23408    28
# 23409    28
# 23410    29
# 23411    30
# Name: Month, Length: 23229, dtype: object

# %%
df.drop(df[(df['Date']=='1975-02-23T02:58:41.000Z')].index, inplace=True)

# %%
df.drop(df[(df['Date']=='1985-04-28T02:53:41.530Z')].index, inplace=True)

# %%
df.drop(df[(df['Date']=='2011-03-13T02:23:34.520Z')].index, inplace=True)

# %%
df['Year'] = pd.to_numeric(df['Year'])
df['Year']
# Out:
# 0        1965
# 1        1965
# 2        1965
# 3        1965
# 4        1965
#          ...
# 23407    2016
# 23408    2016
# 23409    2016
# 23410    2016
# 23411    2016
# Name: Year, Length: 23226, dtype: int64

# %%
corr=df['Magnitude'].corr(df['Root Mean Square'])
print(corr)
# Out:
# 0.06442437015341229

# %%
corr=df['Magnitude'].corr(df['Depth'])
print(corr)
# Out:
# 0.023322032831195702

# %%
df['year']= [int(each.split("/")[2]) for each in df.iloc[:,0]]
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type  Root Mean Square            ID  Source  \
# ...

# %%
df_Year = df.groupby(df['year']).count()
df_Year.describe()
# Out:
#              Date        Time    Latitude   Longitude        Type       Depth  \
# count   52.000000   52.000000   52.000000   52.000000   52.000000   52.000000
# mean   446.653846  446.653846  446.653846  446.653846  446.653846  446.653846
# std     92.015959   92.015959   92.015959   92.015959   92.015959   92.015959
# min    233.000000  233.000000  233.000000  233.000000  233.000000  233.000000
# 25%    388.000000  388.000000  388.000000  388.000000  388.000000  388.000000
# 50%    451.500000  451.500000  451.500000  451.500000  451.500000  451.500000
# 75%    506.500000  506.500000  506.500000  506.500000  506.500000  506.500000
# max    712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
#
#         Magnitude  Magnitude Type  Root Mean Square          ID      Source  \
# count   52.000000       52.000000         52.000000   52.000000   52.000000
# mean   446.653846      446.653846        446.653846  446.653846  446.653846
# ...

# %%
df
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Magnitude Magnitude Type  Root Mean Square            ID  Source  \
# ...

# %%
df['Depth'] = df['Depth'].astype(float)
df['Depth'] =pd.to_numeric(df['Depth'])

# %%
count=df["Year"].value_counts()
count
# Out:
# Year
# 2011    712
# 2007    608
# 1995    589
# 2004    571
# 2010    559
# 2000    553
# 1996    540
# 2005    533
# 1992    532
# 1990    524
# 2009    517
# 2006    508
# 2008    508
# 1994    506
# 1987    489
# 2003    485
# 1986    483
# 2014    480
# 1988    479
# 1989    473
# 2016    469
# 1985    468
# 1984    466
# 1993    465
# 2013    461
# 1997    456
# 1976    447
# 1999    446
# 2015    446
# 2012    445
# 2002    444
# 2001    443
# 1983    442
# 1991    428
# 1977    417
# 1975    401
# 1978    395
# 1973    394
# 1998    388
# 1972    388
# 1971    386
# 1974    355
# 1970    344
# 1979    343
# 1982    340
# 1965    339
# 1980    335
# 1969    322
# 1981    313
# 1968    303
# 1967    255
# 1966    233
# Name: count, dtype: int64

# %%
plt.plot(df["year"].value_counts())

# %%
plt.plot(df["year"].value_counts(),"o")

# %%
#scatter plot Magnitude/Depth
var = 'Magnitude'
data = pd.concat([df['Depth'], df[var]], axis=1)
data.plot.scatter(x=var, y='Depth', ylim=(0,1000));

# %%
fig = px.scatter(data_frame=df,
                 x= df["Magnitude"], 
                 y=df["Depth"], 
                 color= "Year",  
                 title= "Magnitude vs Depth")
fig.show()
# Out:
# <div>                            <div id="e9154a81-d7fe-47bf-a4db-8e54e98feed7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e9154a81-d7fe-47bf-a4db-8e54e98feed7")) {                    Plotly.newPlot(                        "e9154a81-d7fe-47bf-a4db-8e54e98feed7",                        [{"hovertemplate":"Magnitude=%{x}\u003cbr\u003eDepth=%{y}\u003cbr\u003eYear=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965,1965
# ...

# %%
fig = plt.figure(figsize=(30,10))

P1 = fig.add_subplot(1,4,1)
P1 = sns.boxplot(x=df["Source"], y=df["Magnitude"], data=df)

P2 = fig.add_subplot(1,4,2)
P2 = sns.boxplot(x=df["Source"], y=df["Root Mean Square"], data=df)

P3 = fig.add_subplot(1,4,3)
P3 = sns.boxplot(x=df["Source"], y=df["Depth"], data=df)

P4 = fig.add_subplot(1,4,4)
P4 = sns.boxplot(x=df["Source"], y=df["Year"], data=df)

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(data=df,
               x=df['Latitude'],
               y=df['Longitude'],
               hue=df['Magnitude'])
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df,
            x=df['year'],
            y=df['Depth'])
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.lineplot(data=df,
            x=df['year'],
            y=df['Magnitude'])
plt.show()

# %%
#Reference by https://stackoverflow.com/questions/60910962/is-there-any-way-to-draw-india-map-in-plotly
import plotly.express as px
 
fig = px.scatter_geo(df, df['Latitude'],
                     lon=df['Longitude'],
                     color="Magnitude",
                     fitbounds='locations')
fig.show()
# Out:
# <div>                            <div id="13c1f693-c990-47f3-be3e-880e4d1477c0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13c1f693-c990-47f3-be3e-880e4d1477c0")) {                    Plotly.newPlot(                        "13c1f693-c990-47f3-be3e-880e4d1477c0",                        [{"geo":"geo","hovertemplate":"Latitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cbr\u003eMagnitude=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[19.246,1.863,-20.579,-59.076,11.938,-13.405,27.357,-13.309,-56.452,-24.563,-6.807,-2.608,54.636,-18.697,37.523,-51.84,51.251,51.639,52.528,51.626,51.037,51.73,51.775,52.611,51.831,51.948,51.443,52.773,51.772,52.975,52.99,51.536,13.245,51.812,51.762,52.438,51.946,51.738,51.487,53.008,52.184,52.076,51.744
# ...
